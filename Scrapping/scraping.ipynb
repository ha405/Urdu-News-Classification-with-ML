# %%
import os
import json
import time
import random
import zipfile
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # Class Explanation: `NewsScraper`
#
# ## Overview
# The `NewsScraper` class is designed for scraping news articles from three different Urdu news websites: Geo, Jang, and Express. The class has methods that cater to each site's unique structure and requirements. Below, we will go through the class and its methods, detailing what each function does, the input it takes, and the output it returns.
#
# ## Class Definition
#
# ```python
# class NewsScraper:
#     def __init__(self, id_=0):
#         self.id = id_
# ```
#
#
# ## Method 1: `get_express_articles`
#
# ### Description
# Scrapes news articles from the Express website across categories like saqafat (entertainment), business, sports, science-technology, and world. The method navigates through multiple pages for each category to gather a more extensive dataset.
#
# ### Input
# - **`max_pages`**: The number of pages to scrape for each category (default is 7).
#
# ### Process
# - Iterates over each category and page.
# - Requests each category page and finds article cards within `<ul class='tedit-shortnews listing-page'>`.
# - Extracts the article's headline, link, and content by navigating through `<div class='horiz-news3-caption'>` and `<span class='story-text'>`.
#
# ### Output
# - **Returns**: A tuple of:
#   - A Pandas DataFrame containing columns: `id`, `title`, and `link`).
#   - A dictionary `express_contents` where the key is the article ID and the value is the article content.
#
# ### Data Structure
# - Article cards are identified by `<li>` tags.
# - Content is structured within `<span class='story-text'>` and `<p>` tags.

# %%
class NewsScraper:
    def __init__(self,id_=0):
        self.id = id_


  # write functions to scrape from other websites


    def get_express_articles(self, max_pages=1):
        express_df = {
            "id": [],
            "title": [],
            "link": [],
            "content": [],
            "gold_label": [],
        }
        base_url = 'https://jang.com.pk/'
        categories = ['entertainment', 'business', 'sports', 'health-science', 'world']   # saqafat is entertainment category

        # Iterating over the specified number of pages
        for category in categories:
            for page in range(1, max_pages + 1):
                print(f"Scraping page {page} of category '{category}'...")
                url = f"{base_url}/{category}/latest-news{page}"
                response = requests.get(url)
                response.raise_for_status()
                soup = BeautifulSoup(response.text, "html.parser")

                # Finding article cards
                cards = soup.find('ul', class_='tedit-shortnews listing-page').find_all('li')  # Adjust class as per actual site structure
                print(f"\t--> Found {len(cards)} articles on page {page} of '{category}'.")

                success_count = 0

                for card in cards:
                    try:
                        div = card.find('div',class_='horiz-news3-caption')

                        # Article Title
                        headline = div.find('a').get_text(strip=True).replace('\xa0', ' ')

                        # Article link
                        link = div.find('a')['href']

                        # Requesting the content from each article's link
                        article_response = requests.get(link)
                        article_response.raise_for_status()
                        content_soup = BeautifulSoup(article_response.text, "html.parser")


                        # Content arranged in paras inside <span> tags
                        paras = content_soup.find('span',class_='story-text').find_all('p')

                        combined_text = " ".join(
                        p.get_text(strip=True).replace('\xa0', ' ').replace('\u200b', '')
                        for p in paras if p.get_text(strip=True)
                        )

                        # Storing data
                        express_df['id'].append(self.id)
                        express_df['title'].append(headline)
                        express_df['link'].append(link)
                        express_df['gold_label'].append(category.replace('saqafat','entertainment').replace('science','science-technology'))
                        express_df['content'].append(combined_text)

                        # Increment ID and success count
                        self.id += 1
                        success_count += 1

                    except Exception as e:
                        print(f"\t--> Failed to scrape an article on page {page} of '{category}': {e}")

                print(f"\t--> Successfully scraped {success_count} articles from page {page} of '{category}'.")
            print('')

        return pd.DataFrame(express_df)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# List of categories to scrape
cats = ["World News", "Sports News", "Science & Technology News", "Business News", "Entertainment News"]

class NewsScraper:
    def __init__(self, id_=0):
        self.id = id_

    def get_category_links(self, base_url):
        response = requests.get(base_url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        footer_links = {}
        footer_section = soup.find('section', class_='footer')

        if footer_section:
            footer_content = footer_section.find('div', class_='footer_content')
            if footer_content:
                first_row = footer_content.find('div', class_='first_footer')
                if first_row:
                    col = first_row.find('div', class_='col-lg-3 col-md-3 col-sm-6 col-xs-6 h_footer')
                    if col:
                        footer_list = col.find('ul', class_='footer-list')
                        if footer_list:
                            footer_quick1 = footer_list.find('div', class_='footer-quick1')

                            if footer_quick1:
                                for li in footer_quick1.find_all('li'):
                                    a_tag = li.find('a')
                                    if a_tag and 'href' in a_tag.attrs:
                                        category_url = a_tag['href']
                                        category_title = a_tag.get_text(strip=True)

                                        # Check if the category title is in the `cats` list
                                        if category_title in cats:
                                            # Extract last part of the URL to use as the category label
                                            label = re.search(r'/([^/]+)$', category_url).group(1)
                                            footer_links[category_url] = label

        return footer_links

    def get_articles_from_category(self, category_url, label, max_pages=1):
        articles_data = {
            "id": [],
            "title": [],
            "link": [],
            "content": [],
            "gold_label": []
        }

        for page in range(1, max_pages + 1):
            page_url = f"{category_url}?page={page}" if page > 1 else category_url
            response = requests.get(page_url)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')

            try:
                latest_page = soup.find('section', class_='latest_page')
                if latest_page:
                    latest_page_list = soup.find('section', class_='latest_page_list')
                    if latest_page_list:
                        container = latest_page_list.find('div', class_='container')
                        if container:
                            latest_page_right = container.find('div', class_='latest_page_right')
                            if latest_page_right:
                                scroll_pagination = latest_page_right.find('ul', class_='scrollPaginationNew__')
                                if scroll_pagination:
                                    for li in scroll_pagination.find_all('li'):
                                        main_heading = li.find('div', class_='main-heading')
                                        if main_heading:
                                            a_tag = main_heading.find('a')
                                            if a_tag and 'href' in a_tag.attrs:
                                                article_url = a_tag['href']
                                                full_url = f"{article_url}"
                                                article_response = requests.get(full_url)
                                                article_response.raise_for_status()
                                                content_soup = BeautifulSoup(article_response.text, "html.parser")

                                                # Get article title
                                                title_div = content_soup.find('section', class_='detail-page')
                                                if title_div:
                                                    container = title_div.find('div', class_='container')
                                                    if container:
                                                        detail_right = container.find('div', class_='detail-right')
                                                        if detail_right:
                                                            detail_right_top = detail_right.find('div', class_='detail-right-top')
                                                            if detail_right_top:
                                                                title_tag = detail_right_top.find('h1')
                                                                if title_tag:
                                                                    title = title_tag.get_text(strip=True)
                                                                else:
                                                                    title = "No title found"
                                                            
                                                            # Get article content
                                                            detail_content = detail_right.find('div', class_='detail-content')
                                                            if detail_content:
                                                                description_area = detail_content.find('div', class_='description-area')
                                                                if description_area:
                                                                    detail_view_content = description_area.find('div', class_='detail_view_content')
                                                                    if detail_view_content:
                                                                        paragraphs = detail_view_content.find_all('p')
                                                                        article_content = " ".join([para.get_text(strip=True) for para in paragraphs])
                                                                    else:
                                                                        article_content = "No content found"
                                                            else:
                                                                article_content = "No content found"
                                                            
                                                            # Add data to articles_data
                                                            articles_data["id"].append(self.id)
                                                            articles_data["title"].append(title)
                                                            articles_data["link"].append(full_url)
                                                            articles_data["content"].append(article_content)
                                                            articles_data["gold_label"].append(label)  # Set label as gold label

                                                            # Print statement after each article is added
                                                            print(f"Added article: {title}")

                                                            self.id += 1

            except AttributeError as e:
                pass

        return articles_data

    def get_all_articles(self, base_url, max_pages=1):
        category_links = self.get_category_links(base_url)

        all_articles = {
            "id": [],
            "title": [],
            "link": [],
            "content": [],
            "gold_label": []
        }

        for category_url, label in category_links.items():
            category_data = self.get_articles_from_category(category_url, label, max_pages)
            for key in all_articles:
                all_articles[key].extend(category_data[key])

        return pd.DataFrame(all_articles)

# Initialize scraper
scraper = NewsScraper()

# Set the base URL and max pages to scrape
base_url = "https://jang.com.pk/"
articles_df = scraper.get_all_articles(base_url, max_pages=1)

# Save the data to CSV file
articles_df.to_csv("scraped_articles.csv", index=False)

# Confirm that the data is saved
print(f"Data saved to scraped_articles.csv")
# Out:
# Added article: امید ہے ٹرمپ اپنے دوسرے دور صدارت میں جنگیں رکوائیں گے، ترک صدر
# Added article: اسرائیلی وزیراعظم کے دفتر پر نیتن یاہو کے قریبی ساتھیوں کی  حساس ویڈیوز جمع کرنے کا الزام
# Added article: ‎امریکی مسلمانوں، عرب ووٹرز نے ڈیموکریٹس کو چھوڑ دیا: سی اے آئی آر
# Added article: ایمسٹرڈیم: اسرائیلی فٹبال شائقین پر حملہ، 11 زخمی
# Added article: ڈونلڈ ٹرمپ نے سوزی وائلز کو وائٹ ہاؤس کی چیف آف اسٹاف مقرر کر دیا
# Added article: ڈونلڈ ٹرمپ کا روسی صدر پیوٹن سے بات کی خواہش کا اظہار
# Added article: روسی صدر پیوٹن کی ٹرمپ کو انتخاب میں کامیابی پر مبارکباد
# Added article: دنیا کی کوئی طاقت آرٹیکل 370 دوبارہ نہیں لاسکتی، نریندر مودی
# Added article: ٹرمپ کی کامیابی کے بعد خارجہ پالیسی پر انتہاپسندوں کے غلبے کا خدشہ ہے، امریکی جریدہ
# Added article: اسرائیل نے امریکا سے 25 جنگی طیارے خریدنے کا معاہدہ کرلیا
# Added article: وزیر خزانہ کی برطرفی سے جرمن حکومت کو خطرہ لاحق، اپوزیشن کا اعتماد کا ووٹ لینے کا مطالبہ
# Added article: فتح کے بعد فیملی تصویر، ٹرمپ کی اہلیہ غائب، ایلون مسک اہل خانہ کے ساتھ موجود
# Added article: یوگنڈا کی پارلیمنٹ ریسلنگ رنگ میں بدل گئی، ارکان ایک دوسرے پر چڑھ دوڑے
# Added article: حزب اللّٰہ راکٹ حملہ: اسرائیل کی 1 فوجی کی ہلاکت، 3 زخمی ہونے کی تصدیق
# Added article: ڈونلڈ ٹرمپ کی کامیابی سے ایلون مسک کو راتوں رات اربوں ڈالرز کا فائدہ
# Added article: آسٹریلیا: 16 سال سے چھوٹے بچوں کے سوشل میڈیا کے استعمال پر پابندی کی تیاری
# Added article: بارک اوباما نے ڈونلڈ ٹرمپ کے کامیابی پر کیا کہا؟
# Added article: الیکشن میں ہار مانتی ہوں: کملا ہیرس
# Added article: مقبوضہ کشمیر اسمبلی میں خصوصی حیثیت کی بحالی کی قرارداد منظور
# Added article: ڈیموکریٹس نے کملا ہیرس کی شکست کا ذمہ دار جوبائیڈن کو قرار دیدیا
# Added article: جوبائیڈن کا ڈونلڈ ٹرمپ کو فون، جیت پر مبارک باد دی
# Added article: کملا ہیرس نے شکست تسلیم کرلی، ٹرمپ کو فون پر مبارکباد
# Added article: نیتن یاہو کا ٹرمپ کو فون، جیت پر مبارکباد
# Added article: غزہ جنگ نے نیو یارک میں پاکستانی کو کیسے ہرایا؟
# Added article: سعودی ولی عہد شہزادہ محمد بن سلمان کی ڈونلڈ ٹرمپ کو مبارکباد
# Added article: صدارتی الیکشن جیتنے والے ٹرمپ سے متعلق دلچسپ حقیقت
# Added article: ٹیکساس انتخابات، امریکن پاکستانی سلیمان لالانی بھی کامیاب
# Added article: سلمان بھوجانی ٹیکساس اسمبلی کے دوبارہ رکن منتخب
# Added article: امریکی یہودیوں کی اکثریت نے کملا ہیرس کو ووٹ دیا
# Added article: پاکستانی نژاد امریکی رکن کانگریس بننے کا خواب ٹوٹ گیا، ایرن بشیر
# Added article: وزیر دفاع کی برطرفی کیخلاف اسرائیل میں مظاہرے و جلاؤ گھیراؤ
# Added article: حماس نے امریکی صدارتی انتخاب کے نتائج پر ردعمل دے دیا
# Added article: ٹرمپ کی کامیابی، یوکرین جنگ کے حوالے سے یورپ میں تشویش
# Added article: یورپی یونین قیادت کی جانب سے ٹرمپ کو مبارکباد کے پیغامات
# Added article: امریکی عوام کے انتخاب کا احترام کرتے ہیں: چین
# Added article: ٹرمپ نے جیت کا سہرا ایلون مسک کے سر سجا دیا
# Added article: ڈیموکریٹس کی شکست غزہ پر انکے مجرمانہ مؤقف کی قیمت ہے: حماس عہدیدار
# Added article: سربراہانِ مملکت کی ٹرمپ کو دوبارہ صدر بننے پر مبارکباد
# Added article: انتخابات میں کامیابی کے بعد خطاب، ٹرمپ کا اہلیہ میلانیا سے اظہارِ محبت
# Added article: شمالی غزہ میں اسرائیلی حملہ، 20 فلسطینی شہید
# Added article: کوئی نئی جنگ شروع نہیں، جاری جنگیں ختم کرونگا: ڈونلڈ ٹرمپ
# Added article: امریکی صدارتی انتخابات: باراک اوباما کا عوام کیلئے خصوصی پیغام
# Added article: امریکا: 50 ریاستوں میں سے 27 میں ٹرمپ، 19 میں کملا کامیاب
# Added article: سینیٹ میں ریپبلکن کو اکثریت حاصل ہو گئی
# Added article: جارجیا: 5 پولنگ بوتھز پر بم کی غیر مصدقہ دھمکیاں موصول
# Added article: وائٹ ہاؤس کے سامنے ڈونلڈ ٹرمپ کے حامیوں کا جشن شروع
# Added article: وائٹ ہاؤس کے سامنے فلسطین کے حق میں احتجاج ختم
# Added article: امریکی عوام ٹرمپ کو دوبارہ وائٹ ہاؤس بھیجیں گے یا کملا ہیرس کو؟
# Added article: امریکی صدارتی انتخابات، چند مقامات پر تکنیکی مسائل، زیادہ تر ووٹنگ کا عمل ہموار
# Added article: ڈونلڈ ٹرمپ کا پہلا دورِ اقتدار تنازعات سے بھرپور رہا
# Added article: صدارتی امیدوار کملا ہیرس امریکا کی پہلی سیاہ فام خاتون نائب صدر ہیں
# Added article: ڈونلڈ ٹرمپ ایک بار پھر امریکی صدر منتخب ہوگئے
# Added article: وائٹ ہاؤس کے ارد گرد 8 فٹ اونچی لوہے کی باڑ لگادی گئی
# Added article: ڈیموکریٹک امیدوار کملا ہیرس کی فون بینک سے ووٹر کو کال
# Added article: آئرلینڈ نے پہلی مرتبہ فلسطینی سفیر کی تقرری کی منظوری دے دی
# Added article: امریکا آج رات ہائپرسونک جوہری میزائل کا تجربہ کرے گا
# Added article: امریکا، مختلف ریاستوں میں پولنگ ختم ہونے کے مختلف اوقات
# Added article: غزہ و لبنان جنگ کے دوران اسرائیلی وزیر دفاع کو فارغ کردیا گیا
# Added article: امریکی صدارتی انتخاب: جعلی خبروں اور سوشل میڈیا پوسٹس کی روک تھام کیلئے امریکی حکام سرگرم
# Added article: برطانیہ: سارہ شریف قتل کیس، والد کا بچی کی موت کا ذمہ دار ہونے سے انکار
# Added article: امریکی صدارتی انتخاب: ڈونلڈ ٹرمپ نے فلوریڈا میں ووٹ کاسٹ کردیا
# Added article: امریکی صدارتی انتخاب: پانسہ پلٹنے والی ریاستوں میں کس کو کہاں برتری حاصل؟
# Added article: امریکی صدارتی انتخاب تصاویر کے آئینے میں
# Added article: بھارت: نشے میں دھت شخص پٹاخوں کے ڈبے پر بیٹھنے کی شرط میں جان سے ہاتھ دھو بیٹھا
# Added article: مصر: فوجی ہیلی کاپٹر حادثے کا شکار، دو پائلٹ جاں بحق
# Added article: برطانیہ کی ملکہ کمیلا پارکر چیسٹ انفیکشن میں مبتلا ہوگئیں
# Added article: شہدائے جموں نے جانوں کا نذرانہ پیش کرکے قربانی کی عظیم مثال قائم کی، علی رضا سید
# Added article: ایوانکا نے اپنے والد ڈونلڈ ٹرمپ کی انتخابی مہم کو نظرانداز کردیا
# Added article: اسرائیل میں فوج کی تعیناتی پر اراکین کانگریس کا بائیڈن کو خط
# Added article: غزہ میں اسرائیلی فوج کے وحشیانہ حملے جاری، آج مزید 17 فلسطینی شہید
# Added article: یکم نومبر سے اب تک 6 فوجیوں سمیت 7 اسرائیلی ہلاک
# Added article: ڈونلڈ ٹرمپ کا سوشل میڈیا پر مسلمانوں کے حق میں بیان
# Added article: اسرائیلی اخبار کے مالک کا فلسطینیوں کے حق میں بیان، صہیونی حکومت تلملا اٹھی
# Added article: کینیڈا: خالصتان کے حق میں مظاہرے میں شامل مقامی پولیس افسر معطل
# Added article: بھارت میں کملا ہیرس کی کامیابی کیلئے پوجا
# Added article: بھارتی سپریم کورٹ نے اتر پردیش میں مدارس پر پابندی کا فیصلہ کالعدم قرار دے دیا
# Added article: ڈونلڈ ٹرمپ یا کملا ہیرس، امریکی صدارتی انتخاب میں کانٹے کا مقابلہ جاری
# Added article: میرے جیتنے کا 95 فیصد امکان ہے: ٹرمپ کا دعویٰ
# Added article: خواتین ووٹرز ہیرس کی حامی، مردوں کی بڑی تعداد ٹرمپ کیساتھ
# Added article: غزہ: اسرائیلی فوج کی بربریت جاری، مزید 37 فلسطینی شہید
# Added article: امریکی عام انتخابات میں کئی امریکن پاکستانی بھی میدان میں
# Added article: برطانیہ: تارکین وطن کیخلاف گھیرا تنگ کرنے کا فیصلہ
# Added article: ایلون مسک کو ووٹرز کو 10 لاکھ ڈالر دینے کی مہم جاری رکھنے کی عدالتی اجازت مل گئی
# Added article: امریکی انتخابات، امن و امان کے لیے غیرمعمولی سیکیورٹی اقدامات
# Added article: ممکنہ سیکیورٹی معاہدہ، امریکا اور سعودیہ کا تبادلہ خیال
# Added article: کون ہوگا اگلا امریکی صدر؟ ٹرمپ یا کملا، فیصلےکا دن آگیا
# Added article: افریقی جزائر پر تارکین وطن کی کشتی الٹ گئی، 25 افراد ہلاک
# Added article: یحییٰ سنوار نے شہادت سے 3 دن پہلے تک کچھ نہیں کھایا تھا، پوسٹ مارٹم رپورٹ میں انکشاف
# Added article: اگر ڈونلڈ ٹرمپ صدارتی انتخاب جیت گئے تو کونسا ریکارڈ بنائیں گے؟
# Added article: بھارت: اتر اکھنڈ میں بس کھائی میں گرنے سے 36 مسافر ہلاک
# Added article: بھارتی فضائیہ کا مگ 29 جنگی طیارہ گر کر تباہ
# Added article: نیتن یاہو کے دفتر سے حساس معلومات لیک، فوج کے افسر سمیت 5 افراد گرفتار
# Added article: سیستان میں ایرانی ہیلی کاپٹر گر کر تباہ، پاسداران کے بریگیڈیئر سمیت دو افراد جاں بحق
# Added article: امریکی انتخابات: ریاست کینٹکی کے آئین سے لفظ ’احمق‘ ہٹانے پر ووٹنگ بھی ہوگی
# Added article: امریکا: قبل از وقت انتخابات کا اختتام، مسلم ووٹر بے یقینی کا شکار، زیادہ تر ٹرمپ کے حامی
# Added article: کینیڈا: مندر کے باہر ہنگامہ آرائی، تحقیقات شروع
# Added article: ووٹرز قبل از وقت ٹرمپ کی جیت کے دعوے میں نہ آئیں: کملا ہیرس
# Added article: اسرائیل پر بھرپور حملے کی منصوبہ بندی، ایران نے خطے کے ممالک کو آگاہ کردیا
# Added article: اسرائیلی قصبے میٹولا میں اسرائیلی وزیراعظم کی آمد سے قبل ڈرون پھٹ گیا
# Added article: ایڈیلیڈ میچ کے ہیرو حارث رؤف کی سالگرہ
# Added article: قذافی اسٹیڈیم اپ گریڈیشن پروجیکٹ تیزی سے تکمیل کی جانب بڑھنے لگا
# Added article: ویمنز کرکٹ ٹیم کی پرفارمنس میں بہتر آرہی ہے، ارم جاوید
# Added article: ندا ڈار قومی مینز ٹیم کی شاندار پرفارمنس پر خوش
# Added article: بھارتی بورڈ نے ٹیم کے نہ آنے سے آگاہ نہیں کیا، محسن نقوی
# Added article: امید ہے پاکستانی کرکٹ ٹیم فتح کا تسلسل برقرار رکھے گی: مریم نواز
# Added article: بھارت کا چیمپئنز ٹرافی کیلئے پاکستان آنے سے انکار
# Added article: آنیوالے دنوں میں پاکستان کرکٹ ٹیم کھویا ہوا مقام حاصل کر لے گی: عطاء تارڑ
# Added article: حارث رؤف نے ثقلین مشتاق اور شاہین آفریدی کا ریکارڈ توڑ دیا
# Added article: آسٹریلیا کیخلاف 6 کیچ، محمد رضوان نے ورلڈ ریکارڈ برابر کر دیا
# Added article: یورپ میں فٹبال لیگ کھیلنے والی اقصیٰ مشتاق کی پاکستان ٹیم میں شمولیت کا امکان
# Added article: افغانستان کے آل راؤنڈر محمد نبی کا ون ڈے کرکٹ سے ریٹائرمنٹ کا فیصلہ
# Added article: جیسن  گلیسپی کی پاکستان ٹیم کی وائٹ بال فارمیٹ میں کوچنگ کیلئے عدم دلچسپی
# Added article: ویسٹ انڈیز کے فاسٹ بولر الزاری جوزف 2 میچز کیلئے معطل
# Added article: دوسرا ون ڈے: پاکستان نے آسٹریلیا کو شکست دے دی
# Added article: نویں تھل جیپ ریلی کا آغاز، پہلے روز رجسٹریشن، ٹیگنگ، گاڑیوں کی انسپکشن
# Added article: ڈیبیو کیپ کے انتظار سے متعلق کامران غلام کی دلچسپ گفتگو
# Added article: پی ایف ایف نارملائزیشن کمیٹی کا غیرمعمولی کانگریس اجلاس طلب
# Added article: آئی سی سی نے پاک انگلینڈ ٹیسٹ سیریز کی پچز کو اطمینان بخش قرار دے دیا
# Added article: میڈیکل رپورٹ لیک ہونے پر الجیرین باکسر ایمان خلیف کی میڈیا کیخلاف قانونی کارروائی
# Added article: بابر اعظم کو فارم میں واپسی کیلئے ویرات کوہلی کو دیکھنا چاہیے: رکی پونٹنگ
# Added article: نیشنل ویمنز ون ڈے ٹورنامنٹ کل سے کراچی میں شروع ہو گا
# Added article: مکمل فٹ ہونے کے باوجود کریمپس کسی بھی وقت ہو سکتے ہیں: نسیم شاہ
# Added article: قومی ٹیم کا ہیڈ کوچ جیسن گلیسپی کی اکیڈمی کا دورہ
# Added article: پاکستان کے عاصم خان کا لندن اوپن اسکواش میں فاتحانہ آغاز
# Added article: افغانستان نے بنگلادیش کو تر نوالہ بنالیا، پہلے ون ڈے میں 92 رنز سے کامیاب
# Added article: آسٹریلیا کیخلاف ٹی20 سیریز، پاکستان کے 6 کھلاڑیوں کا تربیتی کیمپ ختم
# Added article: فخر زمان نے ٹریننگ کی تصاویر سوشل میڈیا پر پوسٹ کر دیں
# Added article: محمد آصف نے تیسری مرتبہ ورلڈ اسنوکر چیمپئن شپ جیت لی
# Added article: نسیم شاہ انجری سے مکمل فٹ ہو گئے
# Added article: ڈیوڈ وارنر کو پابندی ہٹنے کے بعد کپتانی مل گئی
# Added article: پیٹ کمنز سمیت 5 آسٹریلوی کرکٹرز تیسرا ون ڈے نہیں کھیلیں گے
# Added article: پاکستانی ٹیسٹ کرکٹر ظفر گوہر کا مڈل سکس کاؤنٹی سے معاہدہ
# Added article: محمد آصف قطر میں ہونیوالی ورلڈ اسنوکر چیمپئن شپ کے فائنل میں پہنچ گئے
# Added article: قذافی اسٹیڈیم کی اپ گریڈیشن کا کام تیزی سے جاری
# Added article: پاکستان بیس بال ٹیم کو عرب کلاسک میں شرکت کا این او سی مل گیا
# Added article: موجودہ ہاکی فیڈریشن کے پاس کوئی وژن نہیں، سابق اولمپئن ایاز محمود
# Added article: دو فیڈریشنز سے ہاکی اور کھلاڑیوں کو ہی نقصان پہنچے گا، اصلاح الدین
# Added article: ایفرو ایشیا کپ کی واپسی کیساتھ پاک بھارت کھلاڑیوں کا ایک ساتھ نظر آنے کا امکان
# Added article: الجیریا کی خاتون باکسر ایمان خلیف کی میڈیکل رپورٹ لیک، مرد ثابت
# Added article: پاکستان کرکٹ ٹیم میلبرن سے ایڈیلیڈ روانہ
# Added article: ورلڈ اسنوکر چیمپئن شپ: محمد آصف کوارٹر فائنل میں پہنچ گئے
# Added article: جونیئر ایشیا کپ ہاکی ٹورنامنٹ، قومی ٹیم کا تربیتی کیمپ کراچی میں شروع
# Added article: نسیم شاہ کی انجری تشویش ناک نہیں، ٹیم ذرائع
# Added article: شکیب الحسن کا بولنگ ایکشن مشکوک قرار، ٹیسٹ کرانے کا کہہ دیا گیا
# Added article: سہ فریقی انڈر 19 ٹرافی سیریز کے شیڈول میں رد و بدل
# Added article: نیو یارک میراتھون پاکستانی رنر دانش الہٰی کی نمایاں پرفارمنس
# Added article: پہلا ون ڈے، آسٹریلیا نے پاکستان کو 2 وکٹوں سے شکست دیدی
# Added article: پاکستان بمقابلہ آسٹریلیا، پہلا ون ڈے آج کھیلا جائے گا
# Added article: پاکستان کے تین کھلاڑی اسنوکر چیمپئن شپ کے ناک آؤٹ راؤنڈ میں پہنچ گئے
# Added article: ٹاپ ٹیم کیخلاف ڈیبیو بڑے اعزاز کی بات ہے، عرفان خان نیازی
# Added article: محسن نقوی کی عمیر بٹ کو مسلسل تیسری بار چیئرمین بلجیئم کرکٹ فیڈریشن منتخب ہونے پر مبارکباد
# Added article: استنبول میرا تھون، پاکستانی امجد علی کی نمایاں پرفارمنس
# Added article: پاکستان آرمی نے مینز اینڈ ویمنز نیشنل سوئمنگ چیمپئن شپ جیت لی
# Added article: آسٹریلیا میں حریف پلیئرز سے نبرد آزما ہونے کیلئے پلان ہے: عباس آفریدی
# Added article: ماضی کو بھول کر آگے بڑھنا ہے: کپتان محمد رضوان
# Added article: نیوزی لینڈ نے بھارت کو 3 ٹیسٹ میچز کی سیریز میں وائٹ واش کردیا
# Added article: قذافی اسٹیڈیم کی اپ گریڈیشن کا کام 50 فیصد مکمل
# Added article: پاکستان ٹیم کو ہانگ کانگ سپر سکسز کے فائنل میں شکست
# Added article: آسٹریلیا کیخلاف پہلا ون ڈے: پاکستان نے پلیئنگ الیون کا اعلان کر دیا
# Added article: ساجد خان نے انگلینڈ ٹیسٹ سیریز کی ٹرافیاں اپنے بیٹوں کو دے دیں
# Added article: بھارتی اے کرکٹ ٹیم پر آسٹریلیا میں بال ٹیمپرنگ کا الزام
# Added article: ورلڈ اسنوکر چیمپئن شپ کا فیصلہ کن مرحلہ، پاکستانی کیوئسٹس کا فاتحانہ آغاز
# Added article: رانا نوید الحسن افغانستان انڈر 19 ٹیم کے بولنگ کوچ مقرر
# Added article: ارشد ندیم کو گھر جاکر انعامات دیے، مجھے دفتر بلاکر ہی دے دیں، حیدر علی
# Added article: عبداللّٰہ شفیق بُخار میں مبتلا، تیسرے روز پریکٹس سیشن میں حصہ نہیں لیا
# Added article: محمد رضوان کی کپتانی میں کھیلنا مشکل نہیں ہوگا، صاحبزادہ فرحان
# Added article: آسٹریلیا سے ٹی20 سیریز، 6 کھلاڑیوں کا کیمپ کراچی میں جاری
# Added article: نیشنل اسٹیڈیم کراچی، بڑی الیکٹرونک اسکرین ہٹانے کا کام شروع
# Added article: چیمپئنز ٹرافی میں وقت ہے، توجہ آسٹریلیا کیخلاف سیریز پر ہے: سلمان آغا
# Added article: میلبرن کرکٹ گراؤنڈ کے لانگ روم میں بیٹ رکھے جانے پر بابر اعظم کا ردِعمل
# Added article: ہانگ کانگ سُپر سکسز: پاکستان نے سیمی فائنل کیلئے کوالیفائی کر لیا
# Added article: ہانگ کانگ سُپر سکسز: یو اے ای نے بھارت کو شکست دیکر ایونٹ سے باہر کر دیا
# Added article: پاکستانی پلیئرز کی میلبرن میں دوسرے روز بھی ٹریننگ
# Added article: کرکٹر بین اسٹوکس کے گھر چوری، ایک شخص گرفتار
# Added article: ظہیر عباس پی سی بی گورننگ بورڈ کے رکن بن گئے
# Added article: قومی فٹ بال ٹیم کے ہیڈ کوچ کے معاہدے کی مدت مکمل
# Added article: ڈیرن گوف لاہور قلندرز کے ہیڈ کوچ مقرر
# Added article: ہانگ کانگ سُپر سکسز: پاکستان نے بھارت کو آؤٹ کلاس کر دیا
# Added article: سعودی عرب کی پاکستان سے ویمن فٹبال میچ کھیلنے کی پیشکش
# Added article: محمد حسنین کو آسٹریلیا کیخلاف پہلا ون ڈے کھلانے کا امکان
# Added article: محمد رضوان کو کپتان مقرر کرنا اچھا قدم ہے، شاداب خان
# Added article: ورلڈ اسنوکر چیمپئن شپ، آصف نے فیصلہ کن راؤنڈ میں جگہ بنالی
# Added article: شعیب ملک اور ثانیہ مرزا نے اذہان کی چھٹی سالگرہ الگ الگ منائی
# Added article: رمیز ابراہیم کیلئے گورنر سندھ کا 10 لاکھ روپے انعام کا اعلان
# Added article: چٹوگرام ٹیسٹ میں بھی جنوبی افریقہ کامیاب، ٹیسٹ چیمپئن شپ فائنل میں پہنچنے کی امیدیں برقرار
# Added article: چیمپئنز ٹرافی کیلئے بھارت سے آنے والے تماشائیوں کیلئے خصوصی انتظامات کر رہے ہیں، محسن نقوی
# Added article: پاکستانی ٹی ٹوئنٹی اسکواڈ کے 6 کھلاڑیوں کا تربیتی کیمپ 2 نومبر سے کراچی میں ہو گا
# Added article: آسٹریلیا میں پاکستان 1 بھی ون ڈے جیت گیا تو بہت بڑی کامیابی ہو گی: وسیم اکرم
# Added article: ’سرحدوں نے تقسیم کیا، کرکٹ نے اکٹھا کر دیا‘ منوج تیواڑی کی پاکستانی کھلاڑیوں کیساتھ سوشل میڈیا پوسٹ وائرل
# Added article: محمد رضوان کے کپتان بننے پر شعیب ملک خوش
# Added article: پاکستان کے محموش رضا نے فیدر ویٹ ٹائٹل فائٹ جیت لی
# Added article: بین اسٹوکس کے گھر سے قیمتی اشیاء چوری
# Added article: فخر زمان کے بیٹے کی بولنگ کرواتے ویڈیو وائرل
# Added article: پی سی بی کے رویے میں نرمی، فخر زمان کی مشکلات جلد ختم ہونے کا امکان
# Added article: قومی ہاکی ٹیم کے کھلاڑی ابوبکر کے گھٹنے کی سرجری ہوگئی
# Added article: ڈائریکٹر پی ایس ایل صہیب شیخ مستعفی
# Added article: قذافی اسٹیڈیم لاہور کی اپ گریڈیشن کا کام 45 فیصد مکمل
# Added article: سوشل میڈیا انفلوئنسرز نوجوان لڑکیوں کے دماغ خراب کر رہے ہیں: زویا ناصر
# Added article: سلمان خان کو جان سے مارنے کی دھمکی دینے والا شخص گرفتار
# Added article: والدین نے سدھو موسےوالا کے چھوٹے بھائی کی تصویر جاری کردی
# Added article: منیشا کوئرالہ نے مادھوری ڈکشٹ کی ہم شکل کہلانے پر اپنا ردِ عمل دے دیا
# Added article: شاہ رخ کو دھمکی آمیز کال سے کوئی تعلق نہیں، ایڈووکیٹ فیضان
# Added article: ہنی سنگھ نے سرائیکی گانا پیش کر کے دل جیت لیے
# Added article: ریچا چڈھا اور علی فضل نے 4 ماہ بعد بیٹی کا نام رکھ دیا
# Added article: شاہ رخ خان کو دھمکی کی کال پولیس کو موصول
# Added article: طوبیٰ انور کو کیسے جیون ساتھی کی تلاش؟
# Added article: برطانوی پارلیمنٹ نے ماہرہ خان کو اچیومنٹ ایوارڈ سے نواز دیا
# Added article: کم عمر میں شادی کیوں کی؟ نادیہ خان نے وجہ بتا دی
# Added article: ابھیشیک اور ایشوریا فلم کیلئے اکٹھے، طلاق کی افواہوں کے درمیان نیا پروجیکٹ
# Added article: ایشوریا سے طلاق کی افواہیں، سیمی گریوال کو ابھیشیک کا دفاع کرنا مہنگا پڑ گیا
# Added article: کینسر کی تشخیص کے بعد لگا مرنے والی ہوں، منیشا کوئرالہ
# Added article: امریکی شہری ہوتیں تو کسے ووٹ دیتیں؟ کنگنا رناوت نے بتا دیا
# Added article: ماہرہ خان کی ساڑھی میں نئی تصاویر وائرل
# Added article: امریکی صدارتی انتخابات: ریما نے بھی ووٹ کاسٹ کیا
# Added article: چاہت فتح کے ’بدوبدی‘ پر ماضی کی اداکارہ ممتاز ناراض، بیٹے کا مختلف مؤقف
# Added article: احسن خان کا کرس گیل کیساتھ ڈانس، ویڈیو وائرل
# Added article: انوشکا شرما نے بیٹے کی پہلی تصویر شیئر کر دی
# Added article: کرینہ کا مداح کو سیلفی لینے سے انکار، سوشل میڈیا صارفین کا ملاجلا ردعمل
# Added article: آرٹس کونسل کراچی نے عوامی تھیٹر فیسٹیول کی روایت کو برقرار رکھا ہوا ہے، محمد احمد شاہ
# Added article: سلمان مندر میں آکر معافی مانگیں یا 5 کروڑ ادا کریں، بشنوئی گینگ کی دھمکی
# Added article: 62 بہاریں دیکھنے والی زیبا بختیار نے خوبصورتی کا راز بتا دیا
# Added article: مسرت مصباح کی طلاق پر انکے والدین کا کیا ردِعمل تھا؟
# Added article: سکندر صنم کو بچھڑے 12 برس ہو گئے
# Added article: میرے شوہر نے مجھے ایک ملکہ کی طرح رکھا: عینی زیدی
# Added article: کب شادی کریں گی؟ مہوش حیات  نے بتا دیا
# Added article: ماہرہ خان کو شاہ رخ خان کی کونسی عادت بے حد پسند؟
# Added article: بھارتی اداکارہ کا مدینہ منورہ میں نکاح
# Added article: متھن چکرورتی کی پہلی بیوی ہلینا لیوک امریکا میں انتقال کرگئیں
# Added article: ذیشان صدیقی نے سلمان خان، شاہ رخ خان سے تعلق کی نوعیت بتادی
# Added article: شاہ رخ خان کی تین ماہ سے منت کے باہر بیٹھے فین سے ملاقات
# Added article: امریکی میوزک پروڈیوسر و موسیقار کوئنسی جونز انتقال کرگئے
# Added article: عمیر جیسوال نے دوسری اہلیہ کو خفیہ رکھنے کی وجہ بتا دی
# Added article: میں نے سگریٹ چھوڑ دی: شاہ رخ خان
# Added article: راجپال یادیو صحافی کے سوال پر غصہ، موبائل فون چھین لیا
# Added article: تاپسی پنوں کا فلم ’ڈنکی‘ میں کام سے متعلق بڑا انکشاف
# Added article: عامر خان کی بری عادت فیصلے کرنے میں بہت زیادہ وقت لگانا ہے، کرن رائو
# Added article: اگر بچوں کی لڑائی ہوئی تو شاہ رخ خان کس کا ساتھ دیں گے؟
# Added article: شاہ رخ خان نے ممبئی پولیس کو کھانا بھجوا دیا
# Added article: 38 روزہ ”ورلڈ کلچر فیسٹیول کراچی“ ثقافتی رعنائیاں بکھیرتے ہوئے اختتام پذیر
# Added article: ورلڈ کلچر فیسٹیول کی اختتامی تقریب، عاصم اظہر کی لائیو پرفارمنس
# Added article: انڈر ورلڈ نے مجھے اغوا کرنے کی دھمکی دی تھی، سومی علی
# Added article: اداکارہ لائبہ خان نے عمرہ کی سعادت حاصل کرلی، تصاویر شیئر کردیں
# Added article: سہانا خان نے شاہ رخ کی سالگرہ پر خصوصی پیغام میں کیا کہا؟
# Added article: مرونل ٹھاکر کو مداح کی ایڈیٹ بری لگ گئی
# Added article: علی ظفر نے سعودی عرب میں تاریخ کا سب سے بڑا کنسرٹ کردیا
# Added article: ورلڈ کلچر فیسٹیول کی وائی ایم سی اے گراؤنڈ میں آج اختتامی تقریب، داخلہ مفت
# Added article: شاہ رخ خان کی سالگرہ پر ’فوجی 2‘ کا تحفہ، ٹریلر لانچ
# Added article: شاہ رخ خان نے 59 بہاریں دیکھ لیں
# Added article: مفتی قوی اداکاراؤں کی خفیہ نگرانی کرتے ہیں: وینا ملک
# Added article: حنا پرویز بٹ کی اداکارہ نرگس کی ہر ممکن قانونی مدد کی یقین دہانی
# Added article: دیپیکا پڈوکون اور رنویر سنگھ نے اپنی بیٹی کے نام کا اعلان کردیا
# Added article: ایشوریہ رائے نے بریڈ پٹ کے ساتھ فلم سے کیوں انکار کیا؟
# Added article: دبئی کی شاپ میں شاہ رخ کے شائستہ انداز نے لوگوں کے دل جیت لیے
# Added article: نورا فتحی نے پہلے پہل گانے ’دلبر‘ کی شوٹنگ سے انکار کیوں کیا تھا؟
# Added article: فلموں کی ناکامی کے دور میں فلیٹ کا کرایہ دینا بھی مشکل ہو گیا تھا، کارتک آریان
# Added article: جینیفر لوپیز کا کملا ہیرس کی حمایت کا اعلان، لاطینیوں کا مذاق اڑانے پر ٹرمپ پر شدید تنقید
# Added article: لاہور: اداکارہ نرگس پر شوہر انسپکٹر ماجد بشیر کا مبینہ تشدد
# Added article: شاہ رخ خان نے میرے ناخنوں پر نیل پالش لگائی: ہما قریشی نے دلچسپ کہانی سنا دی
# Added article: ورلڈ کلچر فیسٹیول: آج کا دن پاکستانی موسیقی کے نام
# Added article: 51 بہاریں دیکھنے والی ایشوریا رائے بچن کے اثاثوں کی کل مالیت کتنی ہے؟
# Added article: دولت و شہرت ہونے کے باوجود زندگی میں سکون نہیں ملا تو اللّٰہ کی طرف لوٹا: زاہد احمد
# Added article: اے پی ڈھلون کے گھر پر فائرنگ، ملزم کی عدالت میں آج پیشی
# Added article: عاصم اظہر نے زندگی کی سب سے بہترین سالگرہ کہاں منائی؟
# Added article: سعودی عرب میں بھول بھلیاں 3، سنگھم اگین کی ریلیز پر پابندی عائد
# Added article: ورلڈ کلچر فیسٹیول: 36ویں روز بچوں کیلئے تھیٹر پلے ”علی اور ڈریگن“ پیش
# Added article: پاپارازی کے نامناسب جملے پر ثنا مقبول برہم، گھٹیا حرکت قرار دے دیا
# Added article: خواجہ سلیم کے 2 برس سے غائب ہونے کی وجہ سامنے آ گئی
# Added article: ارجن سے علیحدگی، ملائیکہ کی پوسٹ مرکزِ توجہ بن گئی
# Added article: دلجیت دوسانجھ پر نسل پرستانہ تبصرہ، عدنان سمیع کی اینڈریو ٹیٹ پر تنقید
# Added article: ورلڈ کلچر فیسٹیول: آج بچوں کا تھیٹر پلے ’علی اور ڈریگن‘ پیش کیا گیا
# Added article: فلم ’تیرے نام‘ کی شوٹنگ کے دوران سلمان خان سے ڈر گئی تھی: اندرا کرشنن
# Added article: تابش ہاشمی کا ’جیو‘ پر جلد گیم شو شروع کرنے کا انکشاف
# Added article: فردوس جمال نے اہلِ خانہ کو چھوڑنے کی وجہ بتا دی
# Added article: آج تک سمجھ نہ آیا کہ محبت کسے کہتے ہیں: صبا حمید
# Added article: سلمان خان، ذیشان صدیق کو قتل کی دھمکی دینے والا ملزم گرفتار
# Added article: تابش ہاشمی کیلئے آئی بی اے ایکسیلینس ایوارڈ
# Added article: سلمان کے والد سلیم خان نے ڈیڑھ کروڑ کی لگژری گاڑی خرید لی
# Added article: موت کی دھمکیاں بھی سلمان خان کو طے شدہ پروگرام سے نہ روک سکیں
# Added article: دو فلموں کی ایک جیسی کہانی، پہلی کامیاب ترین فلم، دوسری میں کروڑوں کا نقصان
# Added article: ایشوریہ رائے اور ابھیشک بچن کے درمیان آنیوالی نمرت کور نے خاموشی توڑ دی
# Added article: فردوس جمال کی شادی کے 35 سال بعد طلاق کی تردید
# Added article: کراچی کے مرد پنجاب کے مردوں سے بہتر ہیں: عائشہ طور
# Added article: شاہ رخ خان کے بعد اگلا ’بالی ووڈ کنگ‘ کون؟
# Added article: ارجن کپور کی ملائیکہ اروڑا سے علیحدگی کی تصدیق
# Added article: ’جان پیاری ہے تو 2 کروڑ روپے دو‘ سلمان خان کو ایک اور دھمکی کا سامنا
# Added article: امریکی ماڈل واکر بلینکو کی اننیا پانڈے سے رشتے کی تصدیق
# Added article: سارہ رضا خان کی تنقید پر آئمہ بیگ کا طنزیہ جواب
# Added article: رتن ٹاٹا نے ایک فون کال کیلئے کس بالی ووڈ اداکار سے پیسے ادھار لیے تھے؟
# Added article: ودیا بالن کا 6 ماہ تک آئینے میں چہرہ نہ دیکھنے کا انکشاف
# Added article: فردوس جمال کی اہلیہ نے شادی کے 35 سال بعد خلع لے لی
# Added article: زمبابوین لڑکی کی عاطف اسلم کا گانا گاتے ویڈیو وائرل، مداح حیران
# Added article: سلمان خان کو قتل کی دھمکی دینے کے الزام میں ایک اور شخص گرفتار
# Added article: آرٹس کونسل کراچی: ورلڈ کلچر فیسٹیول میں جمعے، ہفتےکو بغیر ٹکٹ شرکت کا موقع
# Added article: سینئر اپنے جونیئر کی تعریف کرے تو وہ زندگی کا اثاثہ بن جاتی ہے، سجاد علی
# Added article: بھارت میں پہلی بار کروڑ روپے معاوضہ لینے والا اداکار کون؟
# Added article: شلپا شیٹی کے ریسٹورنٹ سے چند منٹوں میں 80 لاکھ کی قیمتی گاڑی چوری
# Added article: صدر لاہور چیمبر نے دکانیں جلد بند کرنے کی حمایت کر دی
# Added article: مہنگائی میں کمی اور معیشت کا آؤٹ لک بہتر ہوا ہے: گورنر اسٹیٹ بینک
# Added article: فی تولہ سونا 2 ہزار روپے مہنگا
# Added article: 52 لاکھ 15 ہزار گوشوارےجمع، 132 ارب روپے سے زائد ٹیکس ادائیگی
# Added article: اسٹاک ایکسچینج کا پہلا سیشن، انڈیکس تاریخ کی بلند ترین سطح پر
# Added article: بجلی کی کس کمپنی کو کتنا جرمانہ کیا گیا، تفصیلات جاری
# Added article: اکتوبر میں ورکرز ترسیلات 3.05 ارب ڈالرز رہیں: اسٹیٹ بینک
# Added article: ملکی زرمبادلہ ذخائر میں11 کروڑ 72 لاکھ ڈالر کی کمی
# Added article: پی ایس ایکس: کاروبار کا مثبت دن، 100 انڈیکس 499 پوائنٹس بڑھ گیا
# Added article: 50 فیصد سے زائد اسمگل شدہ سگریٹس کی فروخت، 300 ارب کا نقصان
# Added article: بینک آف انگلینڈ کا شرح سود میں 0.25 فیصد کمی کا اعلان
# Added article: سونے کی قیمت میں آج بڑی کمی ہو گئی
# Added article: یوٹیلیٹی اسٹورز پر چینی سستی
# Added article: اسٹاک ایکسچینج میں مثبت رجحان، انٹربینک میں ڈالر 4 پیسے سستا
# Added article: ٹرمپ کی جیت، بٹ کوائن تاریخی بلندی پر چلا گیا
# Added article: سونا فی تولہ 1 ہزار روپے سستا
# Added article: ڈونلڈ ٹرمپ کی کامیابی کے بعد عالمی منڈی میں سونے اور خام تیل کی قیمت کم
# Added article: فلپائن نے بغیر آئی ایم ایف پاکستان جیسی صورتحال سے چھٹکارا پایا: سابق گورنر اسٹیٹ رضا باقر
# Added article: اسٹاک ایکسچینج: انڈیکس بلند ترین ریکارڈ کے بعد منفی ہو کر بند
# Added article: صحیح سمت میں جا رہے ہیں، طویل سفر باقی ہے: وزیرِ خزانہ محمد اورنگزیب
# Added article: بجلی مزید مہنگی کرنے کی تیاری
# Added article: پی ایس ایکس: ایک اور ریکارڈ سطح عبور، 100 انڈیکس میں 366 پوائنٹس کا اضافہ
# Added article: سونے کی فی تولہ قیمت میں 500 روپے کی کمی ہوگئی
# Added article: توانائی کے حوالے سے اچھی خبر ہے: وزیرِ اعظم شہباز شریف
# Added article: کراچی کیلئے بجلی 40 پیسے فی یونٹ مہنگی
# Added article: اسٹاک مارکیٹ کی تیزی میں کوئی مصنوعی ببل نظر نہیں آ رہا: عاکف سعید
# Added article: پی ایس ایکس: مسلسل دوسرے روز ایک ہزار پوائنٹس کی تیزی، انڈیکس 92 ہزار کی سطح عبور کرگیا
# Added article: چیئرمین پی سی بی محسن نقوی ٹیم کی فائٹنگ اسپرٹ سے خوش
# Added article: سونے کی فی تولہ قیمت میں 700 روپے کا اضافہ
# Added article: اسٹیٹ بینک نے شرح سود میں ڈھائی فیصد کمی کردی
# Added article: اسٹاک ایکسچینج: انڈیکس 92 ہزار کی سطح عبور کر گیا
# Added article: ایران اسرائیل تناؤ، عالمی منڈی میں خام تیل کی قیمتوں میں اضافہ
# Added article: کوئٹہ: سبزیوں کی قیمتوں میں اضافہ
# Added article: مالیاتی استحکام کی راہ ہموار ہوگئی ہے، وزارت خزانہ
# Added article: ٹیکس اہداف پر نظرثانی معاملے پر آئی ایم ایف سے کوئی ملاقات نہیں ہوئی، ایف بی آر
# Added article: سونے کی فی تولہ قیمت میں 1700 روپے کی بڑی کمی
# Added article: اٹلی کی چکوال میں زیتون کی کاشت مزید بڑھانے کی پیشکش
# Added article: ٹیکس اہداف میں ناکامی، آئی ایم ایف کا منی بجٹ کا مطالبہ
# Added article: اسٹاک ایکسچینج انڈیکس: کاروباری ہفتے میں 865 پوائنٹس کا اضافہ
# Added article: اجناس کی قیمتوں میں 2025 میں 5 اور 2026 میں 2 فیصد تک کمی متوقع ہے، عالمی بینک
# Added article: پی ایس ایکس میں دو دن کی گراوٹ 1893 پوائنٹس اضافے سے برابر ہوگئی
# Added article: مالی سال کے پہلے 4 ماہ میں تجارتی خسارے میں ساڑھے 19 فیصد کمی
# Added article: ہفتہ وار مہنگائی کی شرح بڑھنے کا سلسلہ جاری، 0.10 فیصد بڑھ گئی، رپورٹ
# Added article: ایف بی آر کو 188 ارب 80 کروڑ کے شارٹ فال کا سامنا
# Added article: سونے کی قیمت میں بڑی کمی، 2500 روپے تولہ سستا
# Added article: انٹر بینک: ڈالر 277 روپے 80 پیسے ہو گیا
# Added article: ایل پی جی 2 روپے 89 پیسے فی کلو مہنگی کردی گئی
# Added article: پی ایس ایکس 100 انڈیکس بڑی کمی کے بعد 89 ہزار سے نیچے آگیا
# Added article: چیئرمین ایف بی آر کی ہدایت پر ایڈوانس اسٹاک رجسٹر سسٹم لانچ کردیا گیا
# Added article: سونے کی فی تولہ قیمت میں آج 700 روپے کی کمی
# Added article: انکم ٹیکس گوشوارے جمع کرانے کی تاریخ میں مزید توسیع نہ کرنے کا فیصلہ
# Added article: 820 ارب مالیت کے ٹی بلز نیلامی میں فروخت
# Added article: ایف بی آر نل فائلرز کا ڈیسک آڈٹ کرے: صدر پاکستان ٹیکس بار
# Added article: پی ایس ایکس: مثبت کاروبار پر اختتام کی لہر آٹھویں روز ٹوٹ گئی
# Added article: سونے کی فی تولہ قیمت میں 2900 روپے کا بڑا اضافہ ہوگیا
# Added article: ایف بی آر نے 45 شہروں میں غیر منقولہ جائیداد کی سرکاری قیمت بڑھا دی
# Added article: پی آئی اے کی نجکاری کیلئے صرف ایک بولی دہندہ کی بڈ جمع
# Added article: سعودیہ کا پاکستان میں سرمایہ کاری بڑھانے کا اعلان
# Added article: 56 بڑے شہروں میں پراپرٹی کے سرکاری ریٹس کا نوٹیفکیشن جاری
# Added article: اسٹاک ایکسچینج: انڈیکس 91 ہزار 872 کی نئی بلند ترین سطح کو چھو گیا
# Added article: شیئر بازار میں نئی بلند ترین سطح، اکتوبر میں 9749 پوائنٹس کا اضافہ
# Added article: پاکستان کو 3 ماہ میں 2 ارب 30 کروڑ ڈالر کی بیرونی فنڈنگ موصول
# Added article: سونا فی تولہ 1600 روپے مہنگا
# Added article: ملک بھر میں گھی اور کوکنگ آئل 20 سے 80 روپے کلو مہنگا
# Added article: بیرونی سرمایہ کاروں نے منافع سے 11.87 کروڑ ڈالرز واپس بھیجے
# Added article: انٹر بینک: ڈالر 277 روپے 70 پیسے کا ہو گیا
# Added article: عالمی منڈی میں خام تیل کی قیمت میں 6 فیصد تک کمی
# Added article: پی ایس ایکس میں تاریخ رقم، پہلی بار 100 انڈیکس 90 ہزار سے زائد پوائنٹس پر بند
# Added article: ایل پی جی سرکاری نرخ سے 40 روپے مہنگی بکنے لگی
# Added article: ایف بی آر نے خیبر پختونخوا کی طرف سے برآمدات پر 2 فیصد سیس لگانے کی مخالفت کردی
# Added article: سونا فی تولہ 900 روپے سستا
# Added article: اسٹاک ایکسچینج کا نیا ریکارڈ، 91 ہزار پوائنٹس کا سنگِ میل عبور
# Added article: عالمی مارکیٹ میں خام تیل و گیس کی قیمتیں گر گئیں
# Added article: اسلام آباد، جعلی رسیدیں جاری کرنے پر 2 ریسٹورنٹس سیل
# Added article: ایف بی آر کا ریسٹورنٹس، ریٹیلرز کی جعلی رسید کی رپورٹ کرنے پر انعام کا اعلان
# Added article: اسلام آباد: اتوار بازار میں سرکاری نرخ نامے کی خلاف ورزی کی شکایت
# Added article: پاکستان چین کی مارکیٹ میں پہلا پانڈا بانڈ جاری کرنے کا خواہشمند
# Added article: ایشیائی ترقیاتی بینک پاکستان کو 50 کروڑ ڈالرز قرض دیگا
# Added article: حکومت کی استعمال شدہ گاڑیوں پر پابندی لگانے کی تیاری
# Added article: سونا فی تولہ 2 ہزار روپے مہنگا
# Added article: گورنر پنجاب سے نیویارک چیمبر آف اسمال کارپوریشن کے وفد کی ملاقات
# Added article: مہنگائی میں کمی، معیشت درست سمت میں گامزن ہے: گورنر اسٹیٹ بینک جمیل احمد
# Added article: ٹیکسپو میں 3 دن کے دوران 91 کروڑ ڈالرز کے معاہدے ہوئے: زبیرموتی والا
# Added article: شرحِ مہنگائی 44 ماہ کی کم سطح 7 فیصد سے نیچے آ گئی: ثاقب فیاض مگوں
# Added article: سونا فی تولہ 800 روپے سستا
# Added article: ایکسپو سینٹر لاہور میں پاکستان آٹو پارٹس شو 2024ء کا آغاز
# Added article: بینکوں کو 4255 ارب روپے فراہم کیے ہیں: اسٹیٹ بینک
# Added article: اسٹاک ایکسچینج : انڈیکس 90 ہزار کا سنگِ میل عبور کر گیا
# Added article: امریکی کمپنیاں حکومت کی سرمایہ کار دوست پالیسیوں سے فائدہ اٹھائیں، وزیر خزانہ
# Added article: پاور سیکٹر کا ترسیلی نظام صارفین پر بھاری بوجھ قرار
# Added article: پی ایس ایکس 100 انڈیکس 4 دن میں 3 ہزار 695 پوائنٹس بڑھ گیا
# Added article: بیلجیئن کمپنیوں کی کراچی میں بین الاقوامی ٹیکسٹائل و لیدر نمائش ٹیکسپو 2024 میں شرکت
# Added article: انکم ٹیکس قواعد میں ترامیم، ایکٹو ٹیکس پیئرز لسٹ روزانہ کی بنیاد پر اپ ڈیٹ ہوگی
# Added article: نیپرا نے بجلی 86 پیسے فی یونٹ سستی کردی
# Added article: سونا فی تولہ 2300 روپے سستا
# Added article: 54 بڑے شہروں میں پراپرٹی کے نئے ویلیو ایشن ٹیبلز جاری کرنے کا فیصلہ
# Added article: پاکستان میں 47ویں پولیو وائرس کیس کی تصدیق
# Added article: انسانوں کی عمر کتنی طویل ہو سکتی ہے؟ سائنسدانوں نے پتہ لگا لیا
# Added article: ایم ڈی کیٹ کے ہی مخالف ہوں: ڈاکٹر عذرا فضل پیچوہو
# Added article: قوتِ برداشت میں کمی محسوس ہو تو کیا کریں؟
# Added article: کونسی غذائیں ڈپریشن کم کرتی ہیں؟
# Added article: کوئٹہ: ادویات چھپانے پر 3 فارماسسٹس گرفتار، 2 کی تلاش جاری
# Added article: پنجاب: اسموگ سے آنکھ، ناک، کان، گلے کی بیماریاں پھیلنے لگیں
# Added article: ملک میں ایک اور پولیو کیس کی تصدیق، تعداد 46 ہو گئی
# Added article: بلوچستان: وزیرِ اعلیٰ کا انسدادِ پولیو کیلئے 10 روز میں جامع روڈ میپ مرتب کرنے کا حکم
# Added article: بلوچستان میں انسدادِ پولیو مہم اختتام پزیر، 99 فیصد ہدف حاصل
# Added article: پنجاب: ڈینگی کے مزید 118 کیسز رپورٹ
# Added article: خناق کیا ہے، بچاؤ کیلئے ویکسینیشن کیوں ضروری؟
# Added article: دادو: 7 سالہ بچی میں پولیو وائرس کا شبہ، کراچی کے اسپتال منتقل
# Added article: پنجاب بھر میں ڈینگی کیسز کے اعداد و شمار جاری
# Added article: 51 فیصد افراد کے اینٹی بائیوٹک ادویات از خود استعمال کرنے کا انکشاف
# Added article: پنجاب میں ڈینگی وائرس کے مزید 141 کیسز رپورٹ
# Added article: کراچی: اکتوبر میں ڈینگی کے 363 کیسز رپورٹ
# Added article: ورزش سے قبل درست غذاؤں کا انتخاب کیوں ضروری؟
# Added article: ملک میں پولیو وائرس کے مزید دو کیسز سامنے آگئے
# Added article: بینائی کی حفاظت آپ کے ہاتھوں میں، اس کا خیال رکھیں
# Added article: گزشتہ برس دنیا بھر میں تپ دق کے 82 لاکھ نئے کیسز کی تشخیص ہوئی، عالمی ادارہ صحت
# Added article: اسلام آباد میں چکن گونیا کا پہلا تصدیق شدہ کیس رپورٹ
# Added article: پاکستان میں تپِ دق کے کیسز میں نمایاں اضافہ
# Added article: وزن کم کرنے کیلئے ورزش سے قبل کیا کھائیں اور کیا نہیں؟
# Added article: اورکزئی: حملے کے بعد رکی انسدادِ پولیو مہم کا آج سے دوبارہ آغاز
# Added article: بلوچستان: رواں سال پولیو کے 21 کیسز رپورٹ ہوئے
# Added article: ڈینگی پھیلانے والا مچھر ہی چکن گونیا کا باعث بنتا ہے، ماہرین
# Added article: گورنر سندھ کی ملیریا کے کیسز میں اضافے پر ایکشن کی ہدایت
# Added article: بلوچستان میں انسدادِ پولیو مہم جاری
# Added article: سندھ بھر میں ملیریا کے کیسز میں مسلسل اضافہ
# Added article: موبائل کا غلط انداز میں استعمال ذہنی مسائل کا سبب بن سکتا ہے، تحقیق
# Added article: پنجاب حکومت کا 150 بنیادی مراکز صحت آؤٹ سورس کرنے کافیصلہ
# Added article: کے پی کے: ڈینگی کے مزید 56 کیسز رپورٹ
# Added article: پولیو قطرے پلانے سے انکار کرنیوالے 50 فیصد لوگوں کی نشاندہی کر لی: مراد علی شاہ
# Added article: کے پی کے: 33 اضلاع میں 5 روزہ انسدادِ پولیو مہم کا پہلا مرحلہ شروع
# Added article: ایک سیب روزانہ، واقعی رکھے ڈاکٹر سے دور؟
# Added article: سندھ: 7 روزہ انسدادِ پولیو مہم کا آغاز آج ہو گا
# Added article: سندھ بھر میں سات روزہ انسداد پولیو مہم کا آغاز کل سے ہوگا، ایمرجنسی آپریشن سینٹر
# Added article: لاہور میں آلودگی سے بیماریاں پھیلنے لگیں
# Added article: پولیو سے نمٹنے کیلئے پاکستان و دیگر ممالک میں سعودی منصوبوں پر عملدرآمد
# Added article: ’سُپر فوڈ‘ پالک, کئی موذی امراض کے خلاف مؤثر
# Added article: کراچی: شارجہ سے آنے والی پرواز کے مسافر میں منکی پاکس کی علامات
# Added article: پاکستان میں ایک اور بچہ پولیو سے معذور ہوگیا
# Added article: کراچی میں ڈینگی کے کیسز میں اضافہ، آج شہر میں ڈینگی کے 18 کیسز رپورٹ
# Added article: کراچی: رواں سال ملیریا کے 1 ہزار 935، چکن گونیا کے 172 کیسز رپورٹ
# Added article: کراچی: رواں سال ڈینگی کے 1647 کیسز سامنے آ گئے
# Added article: پنجاب: ڈینگی کے مزید 128 کیسز رپورٹ، 1 مریض کا انتقال
# Added article: چکن گونیا سے بچاؤ کیسے ممکن؟
# Added article: لاہور: فضائی آلودگی بڑھ گئی، بیماریاں پھیلنے کا خطرہ، شہری کیا احتیاطی تدابیر اختیار کریں؟
# Added article: علماء پولیو سے متعلق آگاہی پھیلانے میں کردار ادا کریں: علی امین گنڈاپور
# Added article: پاکستان میں پہلی پولیو ویکسین آصفہ بھٹو کو پلائی گئی: بلاول بھٹو
# Added article: ملک میں پولیو وائرس کا 40 واں کیس رپورٹ
# Added article: لاہور کی فضا میں آلودگی مزید بڑھ گئی
# Added article: خوبصورت اور صحت مند بال اب خواب نہیں
# Added article: مٹھی میں مختلف بیماریوں کے باعث 24 گھنٹوں میں 6 بچے جاں بحق
# Added article: کراچی: نومبر میں ڈینگی کیسز کم ہونے کا امکان
# Added article: چھاتی کے سرطان کے سالانہ 38000 کیسز رپورٹ ہوتے ہیں: ترجمان سندھ حکومت
# Added article: بلوچستان میں رواں سال سب سے زیادہ 20 پولیو کیسز رپورٹ
# Added article: بریسٹ کینسر کیوں ہوتا ہے؟ بچاؤ کیسے ممکن؟
# Added article: عالمی ادارہ صحت نے مصر کو ملیریا سے پاک قرار دے دیا
# Added article: کراچی: 19 اکتوبر کو ڈینگی کے 10 کیسز رپورٹ ہوئے
# Added article: ملک میں رواں سال پولیو سے 3 بچے جاں بحق
# Added article: سندھ میں پولیو وائرس کے مزید 2 کیسز کی تصدیق، ملک بھر میں تعداد 39 ہوگئی
# Added article: پنجاب کو مکمل پولیو فری بنانا ہمارا عزم ہے: وزیرِ اعلیٰ پنجاب
# Added article: کراچی: بچوں میں نمونیا کیسز میں اضافہ
# Added article: ہر 9 میں سے 1 خاتون کو چھاتی کے سرطان کا خطرہ ہے: صدر زرداری
# Added article: روزانہ آدھا چمچ زیتون کے تیل کا استعمال الزائمر کے خطرے کو کم کرتا ہے، تحقیق
# Added article: پنجاب: ڈینگی کے مزید 112 کیسز رپورٹ
# Added article: سندھ میں جان بچانے والی ادویات کی شدید قلت
# Added article: کراچی: 3 روزہ ہیلتھ ایشیاء ایکسپو کا افتتاح
# Added article: سندھ انفیکشس ڈیزیز اسپتال کے عملے کے خناق سے متاثر ہونے کی خبر بے بنیاد قرار
# Added article: طبی عملے کو خناق کی ویکسین کا بوسٹر لگوانے کا فیصلہ
# Added article: دنیا بھر میں شدید غذائی قلت کا شکار 20 لاکھ بچوں کو موت کا خطرہ
# Added article: سندھ انفیکشس ڈیزیز اسپتال کے طبی عملے کو خناق کا بوسٹر لگوانے کا فیصلہ
# Added article: کافی نوش کیجیے، یادداشت بہتر بنائیے!
# Added article: خوبصورت نظر آنا ہے تو چند عادتیں چھوڑ دیں
# Added article: سندھ: جنوری تا اکتوبر رپورٹ ہوئے ملیریا کیسز کی تعداد سامنے آ گئی
# Added article: کس بلڈ گروپ کے افراد کے فالج سے متاثر ہونے کا خطرہ زیادہ؟
# Added article: پاکستان میں ایک اور بچہ پولیو سے معذور ہوگیا
# Added article: روزمرہ کے فیصلے بھی آپ کو تھکاوٹ کا شکار بنادیتے ہیں، تحقیق
# Added article: کراچی: فضائی آلودگی بڑھ گئی، سانس کے مرض میں اضافہ
# Added article: خناق کے کیسز میں غیر معمولی اضافہ، ڈفتھیریا اینٹی ٹاکسن کے 500 وائل محکمۂ صحت سندھ کے حوالے
# Added article: وزن کم کرنے کیلئے کھانے کی مقدار نہیں معیار اہم
# Added article: کراچی: ڈینگی، ملیریا، چکن گونیا و وائرل انفیکشن کے کیسز  میں اضافہ
# Added article: خوبصورت نظر آنے کیلئے ناشتے میں یہ اشیاء لازمی استعمال کریں
# Added article: راولپنڈی: ڈینگی ایمرجنسی کے تحت 4 ہزار سے زائد مقدمات درج
# Added article: کراچی: رواں ماہ ڈینگی کے 114 کیسز رپورٹ
# Added article: نوجوان خواتین میں چھاتی کے کینسر کی عام وجوہات کیا ہیں؟
# Added article: کراچی میں خناق کے کیسز اور اس سے بچوں کی اموات میں اضافہ
# Added article: پنجاب: مزید 149 افراد میں ڈینگی وائرس کی تصدیق
# Added article: پنجاب: ڈینگی کے مزید 160 کیسز رپورٹ
# Added article: کراچی میں کیڑے مکوڑوں سے جلدی امراض پھیلنے لگے
# Added article: کراچی: 10 دن میں 90 ڈینگی کیسز سامنے آ گئے
# Added article: فیصل آباد: دو سر والی 10 دن کی بچی کا کامیاب آپریشن
# Added article: راولپنڈی: ڈینگی کے خطرناک وائرس کی تشخیص، ایمرجنسی نافذ
# Added article: آج لاہور اور کراچی کی فضا مضرِ صحت
# Added article: بیرونِ ملک سے آیا شہری منکی پاکس کی علامات ظاہر ہونے پر اسپتال منتقل
# Added article: کوئٹہ: چین کے تعاون سے خواتین میں حفظانِ صحت کٹس تقسیم
# Added article: پنجاب: ایک اور ڈینگی مریض زندگی کی بازی ہار گیا
# Data saved to scraped_articles.csv

# %%
import pandas as pd

# Load the CSV file
articles_df = pd.read_csv("scraped_articles.csv")

# Replace specific labels in the 'gold_label' column
articles_df['gold_label'] = articles_df['gold_label'].replace({
    "health-science": "Science & Technology",
    "world": "International",
    "sports": "Sports",
    "business":"Business",
    "entertainment":"Entertainment"
})

# Save the updated DataFrame back to the CSV file
articles_df.to_csv("scraped_articles.csv", index=False)

# Confirm the changes
print("CSV file updated with revised gold labels.")
# Out:
# CSV file updated with revised gold labels.

# %% [markdown]
# # Output
# - Save a combined csv of all 3 sites.
